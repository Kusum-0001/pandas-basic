# %%
import pandas as pd

# %%
my_df = pd.read_csv('my_file (1).csv')

# %%
my_df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2  $780,000,000                  $780,000,000
# 1     2     1          7[2]  $579,800,000                  $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                  $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                  $454,751,555
# 4     5  2[4]           NaN  $345,675,146                  $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           20 non-null     int64
#  1   Peak                           9 non-null      object
#  2   All Time Peak                  6 non-null      object
#  3   Actual gross                   20 non-null     object
#  4   Actual gross(in 2022 dollars)  20 non-null     object
#  5   Artist                         20 non-null     object
#  6   Tour title                     20 non-null     object
#  7   Year(s)                        20 non-null     object
#  8   Shows                          20 non-null     int64
#  9   Average gross                  20 non-null     object
#  10  Ref.                           20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
my_df.isnull().sum()
# Out:
# Rank                              0
# Peak                             11
# All Time Peak                    14
# Actual gross                      0
# Actual gross(in 2022 dollars)     0
# Artist                            0
# Tour title                        0
# Year(s)                           0
# Shows                             0
# Average gross                     0
# Ref.                              0
# dtype: int64

# %%
my_df['Peak'] = my_df['Peak'].fillna(0)

# %%
my_df['All Time Peak'] = my_df['All Time Peak'].fillna(0)

# %%
my_df.isnull().sum()
# Out:
# Rank                             0
# Peak                             0
# All Time Peak                    0
# Actual gross                     0
# Actual gross(in 2022 dollars)    0
# Artist                           0
# Tour title                       0
# Year(s)                          0
# Shows                            0
# Average gross                    0
# Ref.                             0
# dtype: int64

# %%
my_df.duplicated().sum()
# Out:
# 0

# %%
my_df['Actual gross(plain)'] = my_df['Actual gross'].str.replace('[$,]',"" , regex=True )
my_df['Actual gross(in 2022 plain)'] = my_df['Actual gross(in 2022 dollars)'].str.replace('[$,]',"" , regex=True)
my_df['Average gross(plain)'] = my_df['Average gross'].str.replace('[$,]',"" , regex=True)

# %%
my_df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2  $780,000,000                  $780,000,000
# 1     2     1          7[2]  $579,800,000                  $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                  $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                  $454,751,555
# 4     5  2[4]             0  $345,675,146                  $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
# ...

# %%
my_df['Actual gross(plain)']
# Out:
# 0        780000000
# 1        579800000
# 2        411000000
# 3        397300000
# 4        345675146
# 5        305158363
# 6        280000000
# 7        257600000
# 8        256084556
# 9        250400000
# 10    229100000[b]
# 11       227400000
# 12       204000000
# 13       200000000
# 14       194000000
# 15       184000000
# 16       170000000
# 17       169800000
# 18    167700000[e]
# 19       150000000
# Name: Actual gross(plain), dtype: object

# %%
my_df = my_df[~my_df['Actual gross(plain)'].str.contains('229100000','167700000',regex=True)]

# %%
my_df = my_df[~my_df['Actual gross(plain)'].str.contains('167700000',regex=True)]

# %%
my_df['Actual gross(plain)']
# Out:
# 0     780000000
# 1     579800000
# 2     411000000
# 3     397300000
# 4     345675146
# 5     305158363
# 6     280000000
# 7     257600000
# 8     256084556
# 9     250400000
# 11    227400000
# 12    204000000
# 13    200000000
# 14    194000000
# 15    184000000
# 16    170000000
# 17    169800000
# 19    150000000
# Name: Actual gross(plain), dtype: object

# %%
my_df['Actual gross(plain)'] = my_df['Actual gross(plain)'].astype('int64')

# %%
my_df['Actual gross(in 2022 plain)'] = my_df['Actual gross(in 2022 plain)'].astype('int64')
my_df['Average gross(plain)'] = my_df['Average gross(plain)'].astype('int64')

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           18 non-null     int64
#  1   Peak                           18 non-null     object
#  2   All Time Peak                  18 non-null     object
#  3   Actual gross                   18 non-null     object
#  4   Actual gross(in 2022 dollars)  18 non-null     object
#  5   Artist                         18 non-null     object
#  6   Tour title                     18 non-null     object
#  7   Year(s)                        18 non-null     object
#  8   Shows                          18 non-null     int64
#  9   Average gross                  18 non-null     object
#  10  Ref.                           18 non-null     object
#  11  Actual gross(plain)            18 non-null     int64
# ...

# %%
my_df.shape
# Out:
# (18, 14)

# %%
my_df.describe()
# Out:
#             Rank       Shows  Actual gross(plain)  \
# count  18.000000   18.000000         1.800000e+01
# mean    9.944444  108.166667         2.979010e+08
# std     5.905852   70.032135         1.617236e+08
# min     1.000000   41.000000         1.500000e+08
# 25%     5.250000   57.000000         1.955000e+08
# 50%     9.500000   85.500000         2.532423e+08
# 75%    14.750000  139.250000         3.355460e+08
# max    20.000000  325.000000         7.800000e+08
#
#        Actual gross(in 2022 plain)  Average gross(plain)
# count                 1.800000e+01          1.800000e+01
# mean                  3.549929e+08          3.967215e+06
# std                   1.554013e+08          3.500382e+06
# min                   1.854231e+08          6.153850e+05
# 25%                   2.532926e+08          1.737067e+06
# 50%                   3.044091e+08          2.746338e+06
# 75%                   3.993783e+08          5.128485e+06
# ...

# %%
my_df.dtypes
# Out:
# Rank                              int64
# Peak                             object
# All Time Peak                    object
# Actual gross                     object
# Actual gross(in 2022 dollars)    object
# Artist                           object
# Tour title                       object
# Year(s)                          object
# Shows                             int64
# Average gross                    object
# Ref.                             object
# Actual gross(plain)               int64
# Actual gross(in 2022 plain)       int64
# Average gross(plain)              int64
# dtype: object

# %%
my_df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2  $780,000,000                  $780,000,000
# 1     2     1          7[2]  $579,800,000                  $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                  $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                  $454,751,555
# 4     5  2[4]             0  $345,675,146                  $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
# ...

# %%
my_df.iloc[:,0:4]
# Out:
#     Rank   Peak All Time Peak  Actual gross
# 0      1      1             2  $780,000,000
# 1      2      1          7[2]  $579,800,000
# 2      3   1[4]          2[5]  $411,000,000
# 3      4   2[7]         10[7]  $397,300,000
# 4      5   2[4]             0  $345,675,146
# 5      6   2[4]         10[9]  $305,158,363
# 6      7  2[10]             0  $280,000,000
# 7      7      0             0  $257,600,000
# 8      9      0             0  $256,084,556
# 9     10      0             0  $250,400,000
# 11    12      0        14[17]  $227,400,000
# 12    13      0             0  $204,000,000
# 13    14  1[20]             0  $200,000,000
# 14    15   2[c]             0  $194,000,000
# 15    16      0             0  $184,000,000
# 16    17      0             0  $170,000,000
# 17    18      0             0  $169,800,000
# 19    20      0             0  $150,000,000

# %%
top_10 = my_df.head()
top_10.plot(x='Artist' , y='Rank' , kind='bar')
# Out:
# <Axes: xlabel='Artist'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank' , kind='line')
# Out:
# <Axes: xlabel='Tour title'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank' , kind='area')
# Out:
# <Axes: xlabel='Tour title'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank' , kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank' , kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank', kind='scatter')
# Out:
# <Axes: xlabel='Tour title', ylabel='Rank'>

# %%
top_10 = my_df.head()
top_10.plot(x='Tour title' , y='Rank' , kind='pie')
# Out:
# <Axes: ylabel='Rank'>

# %%
sale_df['Item'].fillna('0' , inplace=True)

# %%
sale_df.info()

# %%
sale_df['Item'].isnull()
